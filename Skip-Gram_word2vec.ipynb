# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %% [markdown]
# **Hint (by @acg):** [this answer](https://www.quora.com/What-are-the-continuous-bag-of-words-and-skip-gram-architectures/answer/Yanchuan-Sim?srid=keCE) describes pretty well the difference between the two architectures:
#
# - CBOW solves the task of *"predicting the word given its context"*;
# - Skip-gram solves the task of *"predicting the context given a word"*.
#
# By context we mean the surrounding words.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random
import math

threshold = 1e-5
count = Counter(int_words)
total_count = len(int_words)

def subsampling(int_word, t):
    discard_prob = 1 - math.sqrt(t / (count[int_word]/total_count))
    return True if random.random() > discard_prob else False
    

train_words = [iw for iw in int_words if subsampling(iw, threshold)]
# train_words = # The final subsampled word list

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, 1], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), minval=-1, maxval=1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %% [markdown]
# **Hint by @acg:** Negative sampling means that for training the softmax layer we are only going to consider the subset of labels that contain the correct label (which is 1) and a sampled, reduced, number of incorrect labels (which are 0).

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros([n_vocab]), name='biases') # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6526 0.2071 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6068 0.2034 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5173 0.2034 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5988 0.2031 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4955 0.2030 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5568 0.2039 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5521 0.2031 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5321 0.2137 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4671 0.2030 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4632 0.2029 sec/batch
# Nearest to when: broad, different, perro, sledges, koktebel, substances, reggio, warburg,
# Nearest to time: constitute, gev, wordperfect, tense, hypnosis, redirecting, bottle, kaja,
# Nearest to by: few, breakdowns, dzhokhar, finely, verify, kwon, biker, series,
# Nearest to war: come, netherlands, stoppard, mariner, overeating, superhighway, blocs, sport,
# Nearest to up: hamitic, pandora, ambitions, aardvark, poaceae, bloodlust, pliocene, nls,
# Nearest to nine: landlines, noah, precede, holism, antiarrhythmic, taggers, warrington, expropriated,
# Nearest to its: betts, walter, polypeptides, adhered, traders, sheep, zhuang, generalitat,
# Nearest to have: silicates, humberto, humphrey, slug, doubted, herm, emboldened, munition,
# Nearest to resources: dale, serbs, escarpment, telemark, pythagorean, natively, harriers, orson,
# Nearest to brother: padding, eyeless, omnium, foodstuffs, lemmas, allusion, expense, envied,
# Nearest to versions: euroscepticism, universitet, fluorspar, nitrate, cheques, ayya, denaturing, appalachia,
# Nearest to taking: inquisitors, schmitz, newcomen, antisymmetric, trampoline, defamation, leonhart, ubisoft,
# Nearest to assembly: tol, silico, chung, mormons, malden, chimera, rstenberg, steeply,
# Nearest to shown: dili, vichy, prosecutions, agere, aleksei, needling, ccir, appreciation,
# Nearest to question: ebb, chopsticks, scilly, contrabassoon, eruption, eh, tracked, socrate,
# Nearest to dr: trema, ubuweb, rearing, conversation, kintyre, gangsters, septuagint, buonarroti,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4762 0.2049 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3860 0.2034 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3437 0.2028 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2538 0.2029 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2154 0.2029 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1411 0.2028 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0963 0.2034 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0660 0.2264 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0163 0.2661 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9931 0.2654 sec/batch
# Nearest to when: different, broad, com, substances, arid, scope, phone, helped,
# Nearest to time: constitute, older, bottle, contained, hypnosis, gev, part, verify,
# Nearest to by: few, series, captured, inherently, tourism, breakdowns, young, verify,
# Nearest to war: come, burned, sport, netherlands, mariner, pastor, overeating, arm,
# Nearest to up: ambitions, multiplied, bloodlust, pandora, hamitic, twin, event, earnhardt,
# Nearest to nine: landlines, noah, d, precede, dimension, entering, bomber, holism,
# Nearest to its: walter, sheep, traders, tribes, france, their, attractions, adhered,
# Nearest to have: silicates, humberto, humphrey, resources, does, doubted, spying, receive,
# Nearest to resources: dale, have, citizens, serbs, shall, natively, escarpment, orson,
# Nearest to brother: padding, omnium, eyeless, foodstuffs, expense, allusion, metaphysics, having,
# Nearest to versions: euroscepticism, saw, universitet, carcassonne, appearances, contribution, fluorspar, container,
# Nearest to taking: language, communion, newcomen, military, natural, young, inquisitors, meaning,
# Nearest to assembly: tol, chung, silico, root, mormons, chimera, malden, nominated,
# Nearest to shown: appreciation, europe, vichy, prosecutions, dili, aleksei, railroad, sizable,
# Nearest to question: common, confirmed, more, chopsticks, tracked, ebb, identifier, scilly,
# Nearest to dr: trema, missing, conversation, film, ubuweb, millions, rhetoric, authenticity,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9530 0.2261 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9086 0.2646 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8717 0.2466 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8736 0.2110 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8189 0.2098 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8248 0.2031 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7973 0.2039 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7753 0.2134 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7700 0.2033 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7509 0.2055 sec/batch
# Nearest to when: different, broad, expenditure, substances, arid, resentment, com, perro,
# Nearest to time: constitute, tense, gev, benson, older, hypnosis, redirecting, bottle,
# Nearest to by: few, tourism, inherently, finely, series, anthology, outdoor, russian,
# Nearest to war: come, burned, blocs, netherlands, pastor, mariner, sport, superhighway,
# Nearest to up: ambitions, multiplied, hamitic, bloodlust, pandora, resolve, twin, aardvark,
# Nearest to nine: landlines, d, noah, precede, normans, entering, bomber, richard,
# Nearest to its: traders, walter, tribes, sheep, attractions, adhered, france, rebels,
# Nearest to have: silicates, humphrey, humberto, doubted, tantamount, spying, quicktime, does,
# Nearest to resources: dale, escarpment, serbs, galileo, orson, citizens, pythagorean, telemark,
# Nearest to brother: padding, omnium, eyeless, expense, foodstuffs, allusion, purview, having,
# Nearest to versions: euroscepticism, universitet, saw, appearances, nitrate, cheques, mods, genetically,
# Nearest to taking: communion, newcomen, schmitz, language, defamation, trampoline, inquisitors, impeachment,
# Nearest to assembly: tol, chung, silico, mormons, nominated, gu, cabinet, chimera,
# Nearest to shown: vichy, dili, appreciation, exceedingly, aleksei, prosecutions, sinners, needling,
# Nearest to question: tracked, confirmed, eh, ebb, degraded, common, chopsticks, assuming,
# Nearest to dr: conversation, trema, missing, millions, rhetoric, ubuweb, film, glamorous,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7684 0.2237 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7615 0.2228 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7042 0.2044 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6861 0.2086 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7563 0.2123 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7070 0.2211 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6993 0.2214 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7300 0.2259 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6975 0.2043 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6689 0.2063 sec/batch
# Nearest to when: different, broad, expenditure, resentment, reggio, arid, tempted, perro,
# Nearest to time: constitute, gev, benson, tense, hypnosis, johnston, redirecting, insurrection,
# Nearest to by: few, tourism, russian, anthology, finely, country, sharpe, series,
# Nearest to war: burned, mariner, come, netherlands, blocs, pastor, orbiter, superhighway,
# Nearest to up: pliocene, ambitions, multiplied, hamitic, bloodlust, clipping, aardvark, pandora,
# Nearest to nine: d, landlines, three, precede, richard, normans, deaths, eight,
# Nearest to its: traders, attractions, walter, tribes, adhered, geographically, rebels, zhuang,
# Nearest to have: silicates, humphrey, tantamount, humberto, does, doubted, quicktime, spying,
# Nearest to resources: escarpment, serbs, dale, pythagorean, orson, telemark, galileo, clone,
# Nearest to brother: padding, omnium, eyeless, impassable, purview, transposition, expense, having,
# Nearest to versions: euroscepticism, universitet, nitrate, cheques, refining, appalachia, mods, carcassonne,
# Nearest to taking: communion, schmitz, inquisitors, newcomen, lapse, awakened, tracer, defamation,
# Nearest to assembly: tol, chung, cabinet, mormons, nominated, gu, steeply, silico,
# Nearest to shown: vichy, dili, agere, aleksei, prosecutions, kev, sinners, nemesis,
# Nearest to question: eh, ebb, jakarta, degraded, confirmed, truce, assuming, tracked,
# Nearest to dr: conversation, trema, glamorous, rearing, ubuweb, gangsters, film, kintyre,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6667 0.2049 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6811 0.2051 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6258 0.2058 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6340 0.2082 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6649 0.2093 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6429 0.2165 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5819 0.1624 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5378 0.2324 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5217 0.2338 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5184 0.2254 sec/batch
# Nearest to when: different, broad, expenditure, resentment, reggio, sledges, sylvester, arid,
# Nearest to time: constitute, wordperfect, gev, elucidation, benson, johnston, older, hypnosis,
# Nearest to by: few, captured, russian, tourism, series, sharpe, anthology, outdoor,
# Nearest to war: burned, mariner, netherlands, pastor, come, superhighway, blocs, destroyed,
# Nearest to up: pliocene, clipping, hamitic, multiplied, aardvark, dynamo, bloodlust, poaceae,
# Nearest to nine: d, three, eight, landlines, richard, deaths, seven, noah,
# Nearest to its: traders, geographically, attractions, adhered, tribes, decomposes, zhuang, overboard,
# Nearest to have: silicates, humphrey, tantamount, does, humberto, quicktime, arisen, doubted,
# Nearest to resources: escarpment, serbs, orson, pythagorean, telemark, clone, dale, galileo,
# Nearest to brother: eyeless, padding, omnium, impassable, purview, transposition, having, expense,
# Nearest to versions: euroscepticism, universitet, mods, nitrate, koine, appalachia, reductive, semicolon,
# Nearest to taking: schmitz, inquisitors, communion, awakened, newcomen, defamation, changeable, tracer,
# Nearest to assembly: tol, cabinet, chung, mormons, steeply, gu, nominated, silico,
# Nearest to shown: dili, agere, vichy, kev, frames, aleksei, sinners, prosecutions,
# Nearest to question: eh, ebb, degraded, assuming, tracked, confirmed, fro, chopsticks,
# Nearest to dr: conversation, trema, film, glamorous, rearing, gangsters, ubuweb, kintyre,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4923 0.2380 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5035 0.2135 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4600 0.2369 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5262 0.2209 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5204 0.2096 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4806 0.2031 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4529 0.2088 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4069 0.2405 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4254 0.2411 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4077 0.2446 sec/batch
# Nearest to when: broad, different, expenditure, resentment, reggio, secant, amoraim, lingual,
# Nearest to time: constitute, gev, wordperfect, rearrangements, elucidation, johnston, nobleman, korner,
# Nearest to by: few, captured, shea, outdoor, macarius, kwon, sharpe, fortify,
# Nearest to war: burned, mariner, strategic, pastor, destroyed, complementing, superhighway, pronominal,
# Nearest to up: pliocene, clipping, multiplied, hamitic, aardvark, dynamo, bloodlust, lm,
# Nearest to nine: three, landlines, d, elsa, noah, deaths, eight, kildare,
# Nearest to its: traders, adhered, geographically, attractions, tribes, decomposes, zhuang, allocated,
# Nearest to have: silicates, does, arisen, tantamount, humphrey, doubted, humberto, spying,
# Nearest to resources: escarpment, telemark, serbs, region, pythagorean, orson, lowest, clone,
# Nearest to brother: eyeless, impassable, padding, purview, omnium, recruits, expense, transposition,
# Nearest to versions: euroscepticism, universitet, mods, window, koine, nitrate, reductive, appalachia,
# Nearest to taking: schmitz, inquisitors, communion, newcomen, gnp, changeable, defamation, hawker,
# Nearest to assembly: cabinet, tol, steeply, mormons, chung, nominated, thule, gu,
# Nearest to shown: dili, agere, vichy, frames, kev, sinners, aleksei, prosecutions,
# Nearest to question: eh, fro, degraded, answer, assuming, ebb, tracked, chopsticks,
# Nearest to dr: conversation, film, glamorous, trema, ubuweb, gangsters, rearing, kintyre,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4431 0.2059 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4087 0.2082 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4834 0.2053 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4145 0.2208 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4137 0.2195 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4455 0.2244 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3892 0.2241 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3869 0.2095 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4133 0.2226 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3788 0.2066 sec/batch
# Nearest to when: different, expenditure, broad, secant, reggio, resentment, lingual, inducted,
# Nearest to time: constitute, wordperfect, gev, ordinations, korner, elucidation, rearrangements, insurrection,
# Nearest to by: shea, few, captured, kwon, meridians, sundials, finely, sharpe,
# Nearest to war: burned, mariner, strategic, superhighway, maroons, pastor, destroyed, blocs,
# Nearest to up: pliocene, clipping, hamitic, dynamo, aardvark, stansted, bloodlust, mejid,
# Nearest to nine: three, d, eight, landlines, zero, elsa, deaths, seven,
# Nearest to its: traders, geographically, adhered, hutcheson, sheep, columbus, zhuang, decomposes,
# Nearest to have: silicates, arisen, tantamount, doubted, humphrey, does, humberto, spying,
# Nearest to resources: escarpment, telemark, pythagorean, serbs, lowest, provides, region, nitrogenous,
# Nearest to brother: eyeless, purview, impassable, omnium, having, padding, recruits, transposition,
# Nearest to versions: euroscepticism, universitet, window, format, mods, trailer, koine, machines,
# Nearest to taking: schmitz, inquisitors, changeable, newcomen, inability, gnp, communion, awakened,
# Nearest to assembly: cabinet, steeply, legislature, mormons, tol, nominated, thule, chung,
# Nearest to shown: dili, agere, kev, frames, vichy, aleksei, employ, sinners,
# Nearest to question: degraded, answer, fro, eh, assuming, ebb, tracked, redeeming,
# Nearest to dr: conversation, film, glamorous, ubuweb, trema, kintyre, missing, gangsters,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3814 0.2037 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3996 0.2229 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3563 0.2517 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3639 0.2632 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3849 0.2640 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3632 0.2660 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3696 0.2626 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3886 0.2641 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3181 0.2583 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3436 0.2358 sec/batch
# Nearest to when: broad, different, expenditure, amoraim, resentment, reggio, secant, ease,
# Nearest to time: constitute, ordinations, korner, gev, redirecting, insurrection, nobleman, rearrangements,
# Nearest to by: captured, few, sundials, kwon, shea, indies, sharpe, russian,
# Nearest to war: burned, troops, maroons, strategic, mariner, launceston, destroyed, blocs,
# Nearest to up: pliocene, hamitic, clipping, stansted, germani, dynamo, ambitions, bloodlust,
# Nearest to nine: three, eight, zero, total, seven, landlines, d, deaths,
# Nearest to its: traders, adhered, geographically, hutcheson, zhuang, their, rebels, overboard,
# Nearest to have: silicates, arisen, tantamount, doubted, synthesizing, emboldened, collision, does,
# Nearest to resources: escarpment, telemark, fruits, serbs, provides, lowest, have, volcanism,
# Nearest to brother: eyeless, impassable, purview, padding, having, mystic, mande, omnium,
# Nearest to versions: euroscepticism, format, universitet, window, mods, timbres, trailer, machines,
# Nearest to taking: schmitz, inquisitors, changeable, awakened, sofer, inability, communion, inflicting,
# Nearest to assembly: cabinet, legislature, steeply, mormons, thule, tol, chung, dismiss,
# Nearest to shown: dili, agere, kev, frames, aleksei, vichy, cameroun, sinners,
# Nearest to question: answer, degraded, eh, fro, ebb, confirmed, assuming, redeeming,
# Nearest to dr: conversation, film, ubuweb, glamorous, trema, kintyre, missing, rhetoric,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3628 0.2046 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3021 0.2047 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3754 0.2036 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3790 0.2029 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3728 0.2027 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2716 0.2029 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3123 0.2024 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3347 0.2033 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2466 0.2030 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2844 0.2033 sec/batch
# Nearest to when: reggio, amoraim, broad, different, expenditure, secant, lingual, resentment,
# Nearest to time: constitute, ordinations, gev, johnston, korner, rearrangements, insurrection, showman,
# Nearest to by: few, sundials, kwon, captured, shea, abdul, pows, meridians,
# Nearest to war: burned, troops, strategic, maroons, garibaldi, navy, mariner, launceston,
# Nearest to up: pliocene, clipping, dynamo, hamitic, germani, bloodlust, ambitions, stansted,
# Nearest to nine: three, eight, seven, zero, d, one, two, elsa,
# Nearest to its: traders, geographically, adhered, zhuang, photosensitive, hutcheson, congress, rebels,
# Nearest to have: arisen, tantamount, silicates, spying, humphrey, synthesizing, shotguns, collision,
# Nearest to resources: escarpment, telemark, lowest, provides, fruits, serbs, volcanism, citizens,
# Nearest to brother: eyeless, impassable, purview, padding, mystic, having, custis, omnium,
# Nearest to versions: euroscepticism, universitet, format, window, koine, trailer, mods, timbres,
# Nearest to taking: inquisitors, schmitz, sofer, awakened, changeable, hawker, inability, inflicting,
# Nearest to assembly: cabinet, legislature, elections, steeply, thule, judiciary, chairman, mormons,
# Nearest to shown: dili, agere, kev, frames, vichy, cameroun, employ, ccir,
# Nearest to question: answer, degraded, eh, fro, assuming, ebb, redeeming, exclude,
# Nearest to dr: conversation, ubuweb, glamorous, trema, film, gangsters, rhetoric, missing,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2976 0.2044 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2920 0.2028 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3197 0.0944 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2465 0.2032 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2089 0.2032 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2129 0.2035 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2204 0.2029 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2194 0.2027 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2480 0.2038 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1751 0.2028 sec/batch
# Nearest to when: reggio, amoraim, again, resentment, broad, inducted, lingual, secant,
# Nearest to time: constitute, johnston, insurrection, gev, korner, showman, ordinations, rearrangements,
# Nearest to by: few, captured, abdul, sundials, kwon, the, macarius, finely,
# Nearest to war: burned, troops, maroons, strategic, garibaldi, gormenghast, destroyed, launceston,
# Nearest to up: pliocene, clipping, dynamo, bloodlust, germani, hamitic, tolerable, fano,
# Nearest to nine: three, eight, seven, zero, d, two, landlines, elsa,
# Nearest to its: traders, geographically, zhuang, adhered, air, linearity, photosensitive, malleability,
# Nearest to have: tantamount, arisen, silicates, shotguns, resources, collision, synthesizing, doubted,
# Nearest to resources: escarpment, telemark, privatisation, fruits, provides, volcanism, serbs, lowest,
# Nearest to brother: eyeless, impassable, having, padding, purview, mystic, custis, recruits,
# Nearest to versions: euroscepticism, machines, window, format, mods, console, universitet, apple,
# Nearest to taking: schmitz, awakened, inquisitors, sofer, inability, ubisoft, hawker, inflicting,
# Nearest to assembly: cabinet, legislature, steeply, thule, tol, directly, deputies, lingering,
# Nearest to shown: dili, agere, kev, frames, ccir, employ, cameroun, vichy,
# Nearest to question: answer, degraded, eh, assuming, fro, ebb, exclude, xenarthra,
# Nearest to dr: glamorous, conversation, ubuweb, trema, missing, starks, rhetoric, film,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2420 0.2044 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2134 0.2030 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2192 0.2031 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1054 0.2035 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1763 0.2035 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1899 0.2028 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1883 0.2022 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1911 0.2027 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2205 0.2030 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1940 0.2028 sec/batch
# Nearest to when: reggio, amoraim, expenditure, secant, resentment, again, broad, different,
# Nearest to time: constitute, gev, korner, aristarchus, insurrection, denotes, ordinations, johnston,
# Nearest to by: few, sundials, kwon, abdul, teletype, the, griese, finely,
# Nearest to war: burned, troops, maroons, strategic, garibaldi, gormenghast, blockade, contentions,
# Nearest to up: pliocene, clipping, aardvark, dip, dynamo, fano, germani, wrestled,
# Nearest to nine: three, eight, zero, seven, two, landlines, one, pp,
# Nearest to its: traders, geographically, linearity, adhered, malleability, zhuang, commercial, decomposes,
# Nearest to have: tantamount, silicates, arisen, kanem, doubted, related, is, resources,
# Nearest to resources: escarpment, privatisation, have, org, deafblind, serbs, private, provides,
# Nearest to brother: eyeless, impassable, purview, custis, padding, having, recruits, mystic,
# Nearest to versions: euroscepticism, mods, window, universitet, console, erythromycin, trailer, format,
# Nearest to taking: inability, sofer, schmitz, awakened, inquisitors, ubisoft, hotdog, hawker,
# Nearest to assembly: cabinet, legislature, deputies, executive, directly, steeply, judiciary, thule,
# Nearest to shown: dili, agere, kev, frames, cameroun, ccir, employ, devlin,
# Nearest to question: answer, degraded, fro, assuming, eh, exclude, ebb, redeeming,
# Nearest to dr: ubuweb, conversation, glamorous, trema, film, starks, missing, rhetoric,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1733 0.2044 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2355 0.2029 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1828 0.2030 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1452 0.2025 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.2115 0.2029 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1898 0.2030 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1928 0.2040 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1583 0.2026 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1259 0.2028 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1983 0.2029 sec/batch
# Nearest to when: reggio, amoraim, secant, again, resentment, different, lingual, melanchthon,
# Nearest to time: constitute, insurrection, aristarchus, ordinations, gev, korner, nobleman, instantiation,
# Nearest to by: sundials, the, abdul, few, kwon, griese, vote, fenrir,
# Nearest to war: burned, troops, maroons, garibaldi, strategic, attachments, gormenghast, contentions,
# Nearest to up: pliocene, aardvark, tolerable, germani, clipping, vitali, fano, dynamo,
# Nearest to nine: three, eight, seven, zero, one, two, d, pp,
# Nearest to its: traders, geographically, adhered, linearity, emboldened, cliath, malleability, congress,
# Nearest to have: shotguns, doubted, tantamount, fossilization, silicates, arisen, emboldened, spying,
# Nearest to resources: escarpment, privatisation, org, deafblind, private, serbs, provides, access,
# Nearest to brother: eyeless, impassable, purview, custis, having, padding, berghouata, mystic,
# Nearest to versions: universitet, euroscepticism, mods, erythromycin, window, trailer, koine, singularities,
# Nearest to taking: awakened, hotdog, sofer, inquisitors, inflicting, ubisoft, schmitz, inability,
# Nearest to assembly: cabinet, legislature, elections, directly, judiciary, steeply, unicameral, deputies,
# Nearest to shown: agere, dili, kev, cameroun, devlin, essences, ccir, employ,
# Nearest to question: answer, degraded, fro, exclude, eh, ebb, assuming, redeeming,
# Nearest to dr: ubuweb, conversation, glamorous, starks, missing, trema, rhetoric, scenes,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2030 0.2044 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1774 0.2034 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1816 0.2037 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1613 0.2030 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1536 0.2062 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1285 0.2030 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1602 0.2031 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1117 0.2040 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1979 0.2042 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1878 0.2031 sec/batch
# Nearest to when: amoraim, reggio, melanchthon, resentment, again, her, kallisti, inducted,
# Nearest to time: constitute, insurrection, nobleman, aristarchus, ordinations, johnston, korner, gev,
# Nearest to by: the, sundials, abdul, few, cheney, kwon, dealings, fausta,
# Nearest to war: burned, troops, maroons, garibaldi, strategic, metrorail, westermann, missile,
# Nearest to up: pliocene, ambitions, aardvark, fano, germani, dynamo, hamitic, wrestled,
# Nearest to nine: three, eight, seven, zero, one, two, d, five,
# Nearest to its: traders, geographically, cliath, adhered, emboldened, congress, lawmaking, intimidated,
# Nearest to have: tantamount, doubted, arisen, shotguns, emboldened, householder, zedong, humphrey,
# Nearest to resources: escarpment, privatisation, volcanism, private, deafblind, org, telemark, fruits,
# Nearest to brother: having, eyeless, impassable, custis, purview, padding, ossuary, berghouata,
# Nearest to versions: erythromycin, universitet, mods, window, euroscepticism, trailer, koine, format,
# Nearest to taking: awakened, hotdog, inflicting, inquisitors, hawker, sofer, schmitz, haldane,
# Nearest to assembly: cabinet, legislature, deputies, elections, directly, unicameral, senate, exchequer,
# Nearest to shown: agere, dili, devlin, kev, cameroun, vichy, essences, employ,
# Nearest to question: answer, degraded, fro, redeeming, assuming, eh, exclude, ebb,
# Nearest to dr: ubuweb, conversation, glamorous, starks, trema, outrageous, rhetoric, gangsters,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2329 0.2039 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1394 0.2031 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1342 0.2021 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1644 0.2022 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0851 0.2037 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1473 0.2032 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1308 0.2031 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1288 0.2031 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1551 0.0389 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1256 0.2031 sec/batch
# Nearest to when: reggio, lingual, to, amoraim, inducted, melanchthon, kallisti, again,
# Nearest to time: constitute, aristarchus, insurrection, ordinations, gev, korner, fouls, nobleman,
# Nearest to by: the, abdul, sundials, few, kwon, captured, dealings, cheney,
# Nearest to war: burned, troops, garibaldi, strategic, maroons, westermann, blockade, metrorail,
# Nearest to up: pliocene, dynamo, tolerable, aardvark, ambitions, germani, fano, vitali,
# Nearest to nine: three, eight, one, seven, zero, two, d, five,
# Nearest to its: traders, geographically, linearity, cliath, emboldened, adhered, malleability, commercial,
# Nearest to have: tantamount, arisen, shotguns, collision, doubted, householder, sphingosine, fossilization,
# Nearest to resources: escarpment, privatisation, private, org, volcanism, rcito, telemark, deafblind,
# Nearest to brother: eyeless, custis, impassable, having, padding, purview, ossuary, berghouata,
# Nearest to versions: window, erythromycin, euroscepticism, console, compatible, msn, apple, compressors,
# Nearest to taking: inquisitors, awakened, inflicting, hawker, inability, hotdog, schmitz, haldane,
# Nearest to assembly: cabinet, legislature, directly, elections, bicameral, deputies, unicameral, exchequer,
# Nearest to shown: agere, kev, dili, essences, devlin, cameroun, aleksei, vichy,
# Nearest to question: answer, degraded, assuming, eh, redeeming, fro, exclude, ebb,
# Nearest to dr: ubuweb, conversation, glamorous, starks, trema, outrageous, redbrick, rhetoric,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0694 0.2054 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0835 0.2035 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0705 0.2030 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0517 0.2029 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0771 0.2031 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0400 0.2030 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0908 0.2030 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1030 0.2029 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1275 0.2028 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0383 0.2035 sec/batch
# Nearest to when: to, resentment, secant, reggio, amoraim, again, decreases, kallisti,
# Nearest to time: constitute, gev, aristarchus, korner, insurrection, a, nobleman, ordinations,
# Nearest to by: the, sundials, few, captured, abdul, kwon, apportioned, dealings,
# Nearest to war: troops, burned, strategic, maroons, garibaldi, missile, westermann, blockade,
# Nearest to up: dynamo, vitali, pliocene, tolerable, fano, aardvark, erie, earnhardt,
# Nearest to nine: three, eight, seven, zero, two, one, five, total,
# Nearest to its: traders, geographically, cliath, adhered, linearity, emboldened, malleability, commercial,
# Nearest to have: tantamount, arisen, doubted, shotguns, fossilization, householder, kanem, iona,
# Nearest to resources: escarpment, privatisation, deafblind, volcanism, private, org, rcito, fisheries,
# Nearest to brother: custis, padding, purview, impassable, having, eyeless, recruits, ossuary,
# Nearest to versions: window, console, mods, erythromycin, euroscepticism, compatible, compressors, customize,
# Nearest to taking: awakened, hawker, inflicting, inquisitors, sofer, ubisoft, schmitz, haldane,
# Nearest to assembly: cabinet, legislature, deputies, directly, elections, senate, bicameral, assembl,
# Nearest to shown: agere, dili, essences, kev, cameroun, devlin, undervalued, sinners,
# Nearest to question: answer, degraded, eh, fro, assuming, redeeming, exclude, materialist,
# Nearest to dr: ubuweb, glamorous, conversation, starks, trema, desmond, rhetoric, redbrick,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0164 0.2045 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0077 0.2035 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0286 0.2023 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0448 0.2026 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0874 0.2029 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0526 0.2029 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0618 0.2029 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1025 0.2038 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0654 0.2032 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0460 0.2031 sec/batch
# Nearest to when: to, secant, exactly, amoraim, resentment, lingual, again, decreases,
# Nearest to time: constitute, gev, aristarchus, nobleman, instantiation, korner, ordinations, insurrection,
# Nearest to by: the, sundials, kwon, few, abdul, dealings, fausta, executive,
# Nearest to war: troops, strategic, burned, maroons, garibaldi, leyland, missile, gormenghast,
# Nearest to up: vitali, aardvark, pliocene, dynamo, tolerable, misdemeanor, earnhardt, wrestled,
# Nearest to nine: three, eight, seven, one, zero, two, five, total,
# Nearest to its: traders, geographically, adhered, commercial, malleability, emboldened, cliath, linearity,
# Nearest to have: arisen, uninformed, doubted, tantamount, is, related, shotguns, fossilization,
# Nearest to resources: escarpment, org, privatisation, rcito, private, deafblind, volcanism, fisheries,
# Nearest to brother: custis, purview, impassable, eyeless, padding, ossuary, fulda, having,
# Nearest to versions: window, erythromycin, mods, compatible, universitet, compressors, euroscepticism, customize,
# Nearest to taking: haldane, awakened, inquisitors, hawker, inflicting, sofer, ubisoft, hotdog,
# Nearest to assembly: cabinet, legislature, deputies, elections, bicameral, assembl, directly, unicameral,
# Nearest to shown: kev, agere, dili, undervalued, physiological, essences, devlin, cameroun,
# Nearest to question: answer, degraded, fro, eh, redeeming, materialist, assuming, exclude,
# Nearest to dr: ubuweb, glamorous, starks, rhetoric, outrageous, desmond, redbrick, conversation,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0693 0.2044 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0809 0.2034 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0852 0.2033 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0521 0.2032 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0831 0.2034 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0390 0.2030 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0561 0.2028 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0863 0.2032 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1009 0.2032 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0562 0.2036 sec/batch
# Nearest to when: amoraim, to, melanchthon, resentment, exactly, again, lingual, had,
# Nearest to time: constitute, korner, aristarchus, gev, nobleman, ordinations, was, measured,
# Nearest to by: the, sundials, kwon, abdul, captured, few, apportioned, in,
# Nearest to war: troops, strategic, burned, garibaldi, maroons, missile, blockade, contentions,
# Nearest to up: pliocene, vitali, ambitions, dynamo, aardvark, misdemeanor, resolve, earnhardt,
# Nearest to nine: three, eight, seven, zero, two, one, five, total,
# Nearest to its: traders, adhered, geographically, emboldened, cliath, commercial, malleability, with,
# Nearest to have: arisen, uninformed, zedong, fossilization, doubted, tantamount, humphrey, shotguns,
# Nearest to resources: escarpment, rcito, access, org, fisheries, privatisation, deafblind, pastures,
# Nearest to brother: custis, impassable, purview, having, fulda, eyeless, berghouata, bride,
# Nearest to versions: window, mods, compatible, gtk, erythromycin, universitet, compressors, msn,
# Nearest to taking: haldane, awakened, inflicting, inquisitors, hawker, scrape, sofer, ubisoft,
# Nearest to assembly: cabinet, legislature, directly, assembl, hon, nominated, exchequer, chung,
# Nearest to shown: agere, kev, essences, devlin, cameroun, dili, jagiellon, undervalued,
# Nearest to question: answer, degraded, eh, redeeming, materialist, fro, intervenes, exclude,
# Nearest to dr: ubuweb, starks, rhetoric, glamorous, desmond, outrageous, trema, redbrick,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0884 0.2043 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0174 0.2030 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0470 0.2027 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0555 0.2038 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.1054 0.2036 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.0983 0.2041 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1244 0.2027 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0484 0.2029 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0574 0.2026 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0423 0.2209 sec/batch
# Nearest to when: exactly, to, again, lingual, amoraim, melanchthon, decreases, resentment,
# Nearest to time: constitute, gev, aristarchus, measured, was, ordinations, showman, nobleman,
# Nearest to by: the, captured, kwon, abdul, sundials, few, apportioned, dealings,
# Nearest to war: troops, strategic, garibaldi, burned, maroons, missile, leyland, blockade,
# Nearest to up: vitali, aardvark, dynamo, pliocene, tolerable, ambitions, fano, hamitic,
# Nearest to nine: three, eight, seven, zero, two, one, five, piron,
# Nearest to its: traders, geographically, adhered, emboldened, with, cliath, linearity, delineation,
# Nearest to have: arisen, zedong, shotguns, humphrey, kanem, penciler, uninformed, tantamount,
# Nearest to resources: escarpment, rcito, debtors, privatisation, pastures, fisheries, volcanism, org,
# Nearest to brother: custis, impassable, purview, eyeless, fulda, padding, having, murron,
# Nearest to versions: window, erythromycin, mods, gtk, koine, universitet, beos, warping,
# Nearest to taking: haldane, inquisitors, awakened, inflicting, hawker, scrape, inability, jeweled,
# Nearest to assembly: cabinet, legislature, assembl, directly, bicameral, deputies, exchequer, nominated,
# Nearest to shown: agere, kev, devlin, cameroun, essences, jagiellon, slenska, dili,
# Nearest to question: answer, degraded, eh, redeeming, continuations, exclude, intervenes, resistors,
# Nearest to dr: ubuweb, starks, desmond, glamorous, trema, rhetoric, outrageous, redbrick,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9726 0.2039 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0153 0.2041 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0482 0.2030 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0321 0.2027 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0941 0.2029 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0375 0.1870 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9896 0.2032 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9620 0.2040 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0325 0.2032 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9612 0.2032 sec/batch
# Nearest to when: again, to, exactly, decreases, melanchthon, lingual, retire, amoraim,
# Nearest to time: constitute, aristarchus, gev, was, measured, volt, korner, showman,
# Nearest to by: the, captured, few, abdul, dealings, sundials, in, kwon,
# Nearest to war: troops, garibaldi, burned, strategic, maroons, missile, leyland, westermann,
# Nearest to up: vitali, resolve, dynamo, tolerable, misdemeanor, aardvark, bystanders, ambitions,
# Nearest to nine: three, eight, seven, one, zero, two, five, four,
# Nearest to its: traders, geographically, with, commercial, cliath, emboldened, odos, adhered,
# Nearest to have: humphrey, arisen, penciler, fossilization, zedong, shotguns, tantamount, kanem,
# Nearest to resources: escarpment, debtors, rcito, org, volcanism, tools, deceit, deafblind,
# Nearest to brother: custis, impassable, fulda, purview, eyeless, having, possessions, berghouata,
# Nearest to versions: window, compatible, mods, gtk, erythromycin, beos, customize, annunciation,
# Nearest to taking: haldane, awakened, inquisitors, inflicting, hawker, scrape, ubisoft, operator,
# Nearest to assembly: directly, cabinet, legislature, assembl, deputies, bicameral, nominated, gu,
# Nearest to shown: kev, agere, essences, physiological, slenska, algae, ccir, devlin,
# Nearest to question: answer, degraded, eh, redeeming, materialist, continuations, intervenes, stature,
# Nearest to dr: ubuweb, starks, glamorous, desmond, redbrick, trema, outrageous, rhetoric,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0176 0.2043 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9485 0.2028 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0252 0.2026 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0069 0.2035 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9981 0.2029 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9774 0.2031 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9205 0.2030 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9611 0.2027 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9473 0.2032 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9899 0.2034 sec/batch
# Nearest to when: again, to, inhaling, decreases, lingual, exactly, quickly, secant,
# Nearest to time: constitute, was, measured, aristarchus, gev, korner, a, instantiation,
# Nearest to by: the, dealings, of, abdul, few, in, linkage, kwon,
# Nearest to war: troops, strategic, garibaldi, maroons, burned, missile, leyland, petitcodiac,
# Nearest to up: vitali, tolerable, earnhardt, backbone, wrestled, misdemeanor, aardvark, dynamo,
# Nearest to nine: three, eight, seven, zero, two, one, five, four,
# Nearest to its: traders, with, geographically, commercial, cliath, odos, adhered, linearity,
# Nearest to have: is, arisen, humphrey, other, kanem, presumably, penciler, zedong,
# Nearest to resources: org, debtors, escarpment, phosphates, resource, rcito, tools, fisheries,
# Nearest to brother: custis, purview, impassable, eyeless, padding, murron, recruits, having,
# Nearest to versions: mods, erythromycin, window, compatible, annunciation, beos, customize, universitet,
# Nearest to taking: hawker, haldane, inquisitors, awakened, ubisoft, scrape, inability, inflicting,
# Nearest to assembly: cabinet, directly, assembl, legislature, bicameral, deputies, elections, gu,
# Nearest to shown: kev, undervalued, assumed, agere, devlin, dili, slenska, jagiellon,
# Nearest to question: answer, eh, degraded, materialist, redeeming, continuations, intervenes, fro,
# Nearest to dr: ubuweb, desmond, glamorous, rhetoric, starks, outrageous, trema, redbrick,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9908 0.2043 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9917 0.2027 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9585 0.2028 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0228 0.2027 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0438 0.2035 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9437 0.2033 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9957 0.2025 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9752 0.2027 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0106 0.2030 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0022 0.2023 sec/batch
# Nearest to when: again, decreases, inhaling, exactly, secant, to, ease, quickly,
# Nearest to time: was, measured, constitute, aristarchus, korner, gev, instantiation, a,
# Nearest to by: the, in, of, abdul, dealings, sundials, kwon, few,
# Nearest to war: troops, strategic, garibaldi, burned, leyland, maroons, missile, petitcodiac,
# Nearest to up: vitali, misdemeanor, earnhardt, aardvark, wrestled, tolerable, to, resolve,
# Nearest to nine: three, seven, eight, one, zero, two, five, four,
# Nearest to its: with, traders, geographically, cliath, adhered, emboldened, odos, arguably,
# Nearest to have: penciler, presumably, arisen, is, shotguns, zedong, humphrey, fossilization,
# Nearest to resources: org, escarpment, rcito, pastures, resource, phosphates, tools, fisheries,
# Nearest to brother: custis, eyeless, purview, impassable, padding, murron, having, fulda,
# Nearest to versions: mods, window, compatible, beos, erythromycin, annunciation, universitet, customize,
# Nearest to taking: haldane, hawker, scrape, inquisitors, operator, awakened, ubisoft, inflicting,
# Nearest to assembly: cabinet, directly, assembl, legislature, bicameral, deputies, nominated, hon,
# Nearest to shown: devlin, kev, jagiellon, ccir, physiological, aleksei, agere, undervalued,
# Nearest to question: answer, materialist, degraded, eh, gains, intervenes, continuations, stature,
# Nearest to dr: ubuweb, desmond, glamorous, rhetoric, redbrick, starks, outrageous, missing,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0062 0.2054 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9958 0.2032 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 4.0063 0.2028 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0190 0.2030 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0244 0.2033 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9852 0.2030 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9868 0.2035 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9552 0.2031 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9577 0.2025 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0227 0.2038 sec/batch
# Nearest to when: exactly, to, decreases, resentment, again, expenditure, regrouping, melanchthon,
# Nearest to time: was, constitute, aristarchus, measured, korner, delay, ordinations, gev,
# Nearest to by: the, in, of, sundials, to, and, digits, kwon,
# Nearest to war: troops, strategic, garibaldi, maroons, burned, leyland, missile, petitcodiac,
# Nearest to up: resolve, vitali, backbone, aardvark, pliocene, wrestled, tolerable, to,
# Nearest to nine: three, eight, seven, zero, one, two, five, four,
# Nearest to its: with, traders, geographically, odos, commercial, cliath, impoverishment, adhered,
# Nearest to have: is, arisen, penciler, presumably, shotguns, zedong, humphrey, that,
# Nearest to resources: pastures, escarpment, resource, debtors, phosphates, rcito, org, access,
# Nearest to brother: custis, eyeless, impassable, purview, padding, murron, having, fulda,
# Nearest to versions: mods, compatible, beos, window, erythromycin, annunciation, typeset, gtk,
# Nearest to taking: haldane, operator, awakened, inflicting, inquisitors, hawker, scrape, natural,
# Nearest to assembly: cabinet, bicameral, assembl, legislature, directly, deputies, nominated, hon,
# Nearest to shown: devlin, jagiellon, kev, physiological, ccir, cameroun, slenska, agere,
# Nearest to question: answer, eh, degraded, gains, continuations, materialist, redeeming, stature,
# ...
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7910 0.2431 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.7900 0.2531 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8686 0.2591 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8777 0.2447 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8177 0.2450 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8553 0.2466 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8882 0.2372 sec/batch
# Nearest to when: to, once, again, exactly, first, peredeo, the, but,
# Nearest to time: was, which, a, measured, instantiation, little, coincides, delay,
# Nearest to by: the, of, in, and, a, as, to, with,
# Nearest to war: troops, strategic, garibaldi, leyland, petitcodiac, deutschland, world, maroons,
# Nearest to up: to, at, deformed, mahabad, carmack, ashton, back, earnhardt,
# Nearest to nine: one, eight, two, three, seven, zero, five, four,
# Nearest to its: with, first, of, the, a, described, in, it,
# Nearest to have: that, some, several, all, is, other, in, been,
# Nearest to resources: resource, pastures, phosphates, ores, productive, irrigated, wrath, access,
# Nearest to brother: custis, lfr, son, cultivated, padding, clan, murron, lusp,
# Nearest to versions: fughetta, version, compatible, mods, based, vr, glycosylation, annunciation,
# Nearest to taking: tahrir, recover, legions, mifune, sainsbury, hom, ambassadors, natural,
# Nearest to assembly: assembl, hon, legislature, directly, unicameral, seats, elections, bids,
# Nearest to shown: now, element, devlin, assumed, undervalued, jagiellon, slenska, ccir,
# Nearest to question: answer, questions, whether, eh, stature, norris, asks, continuations,
# Nearest to dr: desmond, dre, redbrick, glamorous, daddy, ubuweb, picketing, bixby,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8327 0.2518 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8577 0.2031 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8610 0.2032 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8596 0.2147 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8512 0.2023 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8872 0.2029 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8562 0.2031 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8437 0.2028 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.9087 0.2028 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.9026 0.2031 sec/batch
# Nearest to when: to, once, again, first, exactly, the, dickerson, quickly,
# Nearest to time: was, which, his, little, ordinations, period, pleistocene, aristarchus,
# Nearest to by: the, of, in, and, a, as, to, with,
# Nearest to war: troops, garibaldi, strategic, deutschland, irma, blockade, during, world,
# Nearest to up: to, at, deformed, mahabad, sumbawa, carmack, before, backbone,
# Nearest to nine: one, eight, three, two, zero, seven, five, four,
# Nearest to its: with, first, of, the, in, a, and, same,
# Nearest to have: some, that, several, is, been, all, many, other,
# Nearest to resources: resource, ores, pastures, wrath, phosphates, irrigated, productive, access,
# Nearest to brother: custis, lfr, son, cultivated, clan, having, murron, incongruity,
# Nearest to versions: fughetta, version, compatible, mods, herrn, annunciation, glycosylation, based,
# Nearest to taking: tahrir, recover, ambassadors, legions, supersedes, natural, grammys, mifune,
# Nearest to assembly: assembl, hon, unicameral, directly, legislature, elections, seats, dur,
# Nearest to shown: now, element, devlin, slenska, jagiellon, bollywood, ccir, duodecimal,
# Nearest to question: answer, whether, questions, eh, norris, stature, issue, asks,
# Nearest to dr: desmond, dre, picketing, daddy, redbrick, glamorous, ubuweb, bixby,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8705 0.2041 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8526 0.2027 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8394 0.2030 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8111 0.2020 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8823 0.2186 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8377 0.2065 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9613 0.2064 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8829 0.2054 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9241 0.2169 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8143 0.2052 sec/batch
# Nearest to when: to, once, again, dickerson, first, but, the, peredeo,
# Nearest to time: was, which, early, his, little, in, period, aristarchus,
# Nearest to by: the, of, in, and, as, a, to, with,
# Nearest to war: troops, garibaldi, world, during, strategic, maroons, deutschland, conflict,
# Nearest to up: to, at, deformed, sumbawa, carmack, mahabad, back, backbone,
# Nearest to nine: one, eight, two, zero, three, seven, five, four,
# Nearest to its: with, first, the, of, in, and, a, early,
# Nearest to have: some, several, that, been, is, there, all, many,
# Nearest to resources: pastures, ores, resource, phosphates, irrigated, wrath, productive, natural,
# Nearest to brother: custis, lfr, son, cultivated, clan, bond, murron, incongruity,
# Nearest to versions: fughetta, version, herrn, annunciation, mods, compatible, burg, alpina,
# Nearest to taking: tahrir, recover, legions, ambassadors, grammys, landsat, mifune, jack,
# Nearest to assembly: assembl, unicameral, elections, legislature, cabinet, hon, directly, fitting,
# Nearest to shown: now, element, slenska, bollywood, devlin, jagiellon, assumed, baluchistan,
# Nearest to question: answer, whether, questions, eh, issue, stature, asks, norris,
# Nearest to dr: desmond, dre, picketing, daddy, redbrick, glamorous, ubuweb, bixby,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7840 0.2228 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8595 0.2063 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8028 0.2027 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8816 0.2029 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8303 0.2025 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8505 0.2025 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8837 0.1158 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8317 0.2030 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8151 0.2031 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8656 0.2035 sec/batch
# Nearest to when: to, the, once, first, again, in, but, quickly,
# Nearest to time: was, which, aristarchus, little, early, his, ordinations, in,
# Nearest to by: the, in, of, and, a, as, to, been,
# Nearest to war: troops, garibaldi, world, strategic, leyland, eamonn, during, blockade,
# Nearest to up: to, at, mahabad, deformed, before, took, carmack, sumbawa,
# Nearest to nine: one, eight, two, three, zero, seven, four, five,
# Nearest to its: with, first, the, of, and, which, a, hurst,
# Nearest to have: some, that, several, been, many, there, other, all,
# Nearest to resources: pastures, resource, phosphates, ores, irrigated, wrath, chromium, productive,
# Nearest to brother: custis, son, cultivated, lfr, clan, incongruity, having, muhammad,
# Nearest to versions: version, fughetta, compatible, mods, annunciation, based, herrn, quadra,
# Nearest to taking: recover, tahrir, mifune, ambassadors, legions, sparrowhawk, assumption, sainsbury,
# Nearest to assembly: assembl, directly, legislature, unicameral, elections, dur, bicameral, bids,
# Nearest to shown: now, element, slenska, bollywood, jagiellon, undervalued, sayed, devlin,
# Nearest to question: answer, whether, questions, eh, issue, amass, stature, norris,
# Nearest to dr: desmond, picketing, dre, redbrick, daddy, glamorous, ubuweb, bixby,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7988 0.2040 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8097 0.2027 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8457 0.2028 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7843 0.2027 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8260 0.2027 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8443 0.2028 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8887 0.2032 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7282 0.2029 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8181 0.2025 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7947 0.2024 sec/batch
# Nearest to when: to, first, once, the, again, quickly, exactly, but,
# Nearest to time: was, early, which, in, period, aristarchus, the, little,
# Nearest to by: the, of, and, in, as, a, to, with,
# Nearest to war: troops, garibaldi, world, strategic, leyland, during, maroons, irma,
# Nearest to up: at, to, mahabad, carmack, sumbawa, deformed, allowed, before,
# Nearest to nine: one, eight, three, two, zero, seven, five, four,
# Nearest to its: with, of, the, first, in, a, and, an,
# Nearest to have: that, some, several, is, been, there, many, other,
# Nearest to resources: pastures, resource, phosphates, irrigated, ores, natural, productive, hydropower,
# Nearest to brother: custis, son, cultivated, lfr, incongruity, muhammad, murron, padding,
# Nearest to versions: version, fughetta, mods, compatible, alpina, quadra, clones, annunciation,
# Nearest to taking: tahrir, recover, mifune, ambassadors, grammys, neuropathy, legions, barricade,
# Nearest to assembly: assembl, bicameral, elections, legislative, cabinet, legislature, unicameral, directly,
# Nearest to shown: element, now, bollywood, undervalued, devlin, jagiellon, sayed, slenska,
# Nearest to question: answer, whether, questions, eh, stature, issue, norris, asks,
# Nearest to dr: desmond, dre, picketing, redbrick, daddy, glamorous, ubuweb, livebearers,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7624 0.2035 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8418 0.2027 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8447 0.2026 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8469 0.2026 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8292 0.2022 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9012 0.2026 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8636 0.2029 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8572 0.2024 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8032 0.2027 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8407 0.2026 sec/batch
# Nearest to when: to, first, the, once, a, exactly, but, for,
# Nearest to time: was, which, early, in, the, period, a, little,
# Nearest to by: the, of, in, and, as, a, to, with,
# Nearest to war: troops, garibaldi, leyland, irma, world, strategic, chrome, eamonn,
# Nearest to up: at, to, mahabad, sumbawa, carmack, deformed, before, out,
# Nearest to nine: one, eight, three, two, zero, seven, five, four,
# Nearest to its: with, of, the, first, in, and, an, a,
# Nearest to have: some, that, several, all, been, other, there, and,
# Nearest to resources: resource, pastures, phosphates, ores, productive, irrigated, chromium, andreessen,
# Nearest to brother: son, custis, lfr, cultivated, clan, incongruity, muhammad, murron,
# Nearest to versions: fughetta, version, mods, compatible, alpina, herrn, glycosylation, timesharing,
# Nearest to taking: tahrir, recover, ambassadors, mifune, supersedes, legions, natural, hom,
# Nearest to assembly: assembl, unicameral, elections, bicameral, legislature, directly, cabinet, legislative,
# Nearest to shown: now, element, bollywood, devlin, undervalued, jagiellon, slenska, sayed,
# Nearest to question: answer, whether, questions, eh, issue, stature, norris, joab,
# Nearest to dr: dre, desmond, redbrick, daddy, picketing, ubuweb, glamorous, bixby,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8764 0.2042 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8477 0.2026 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8212 0.2028 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8472 0.2028 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8805 0.2028 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8438 0.2031 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8163 0.2028 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8555 0.2029 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8089 0.2027 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8175 0.2025 sec/batch
# Nearest to when: to, the, once, in, first, but, this, a,
# Nearest to time: was, which, period, early, in, pleistocene, by, the,
# Nearest to by: the, of, and, in, as, to, a, with,
# Nearest to war: troops, garibaldi, world, conflict, during, leyland, deutschland, irma,
# Nearest to up: at, to, sumbawa, deformed, mahabad, carmack, outside, anaximander,
# Nearest to nine: one, eight, three, two, zero, seven, five, four,
# Nearest to its: with, of, the, first, in, and, which, a,
# Nearest to have: some, that, is, several, other, there, all, been,
# Nearest to resources: resource, pastures, phosphates, ores, irrigated, chromium, andreessen, productive,
# Nearest to brother: son, custis, lfr, cultivated, clan, lusp, murron, catalysed,
# Nearest to versions: version, fughetta, mods, compatible, herrn, alpina, timesharing, glycosylation,
# Nearest to taking: tahrir, supersedes, recover, ambassadors, assumption, mifune, grammys, legions,
# Nearest to assembly: assembl, dur, unicameral, hon, legislature, elections, directly, cabinet,
# Nearest to shown: now, element, jagiellon, bollywood, devlin, duodecimal, slenska, diaper,
# Nearest to question: answer, whether, questions, eh, issue, stature, norris, joab,
# Nearest to dr: desmond, dre, ubuweb, redbrick, daddy, picketing, healing, glamorous,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8630 0.2043 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8145 0.2035 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9199 0.2033 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9087 0.2030 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8813 0.2024 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8292 0.2029 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7723 0.2019 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8385 0.2024 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7265 0.2033 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8566 0.2031 sec/batch
# Nearest to when: to, the, first, but, in, this, once, exactly,
# Nearest to time: was, period, little, which, early, his, in, the,
# Nearest to by: the, of, in, and, as, to, a, with,
# Nearest to war: troops, garibaldi, world, conflict, during, leyland, ii, strategic,
# Nearest to up: at, carmack, to, sumbawa, deformed, lifeguard, back, billie,
# Nearest to nine: one, eight, two, zero, three, seven, five, four,
# Nearest to its: with, of, the, first, in, from, a, an,
# Nearest to have: some, several, that, been, there, is, other, are,
# Nearest to resources: resource, phosphates, pastures, ores, chromium, productive, wrath, irrigated,
# Nearest to brother: custis, son, lfr, cultivated, catalysed, clan, murron, padding,
# Nearest to versions: version, fughetta, mods, herrn, based, alpina, compatible, timesharing,
# Nearest to taking: tahrir, supersedes, recover, grammys, ambassadors, mifune, assumption, jack,
# Nearest to assembly: assembl, elections, unicameral, cabinet, dur, hon, seats, legislature,
# Nearest to shown: now, element, devlin, slenska, ccir, duodecimal, jagiellon, bollywood,
# Nearest to question: answer, questions, whether, issue, eh, joab, asks, norris,
# Nearest to dr: desmond, daddy, dre, ubuweb, redbrick, picketing, livebearers, macaulay,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8542 0.2046 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8294 0.2030 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
